# %%
print('enter your first name') #question 1
N=input()
str(N)
print('enter your last name')
L=input()
str(L)
print(L,' ',N)
#question 2
# Out:
# enter your first name
# Ons
# enter your last name
# Hammouda
# Hammouda   Ons

# %% [markdown]
# # Q2

# %%
x=input('enter an integer ')
a=int(x)
xx=x+x
b=int(xx)
xxx=x+x+x
c=int(xxx)
s=a+b+c
print(a,'+',b,'+',c,'=',s)
# Out:
# enter an integer 5
# 5 + 55 + 555 = 615

# %% [markdown]
# # Q3

# %%
x=input('enter a number ')
print(x[-1])
p=x[-1]
if p in range(0,9,2):
    print(x,'is even')
else: 
    print(x,'is odd')
# Out:
# enter a number 856
# 6
# 856 is odd

# %% [markdown]
# # Q4

# %%
x=input('enter a number ')
i=int(x)
if i in range(2000,3201):
    p=i
else:
    print('enter a number between 2000 and 3200')
    p=input()
    p=int(p)
a=p%7
print(p,'%7=',a)
if a==0:
    p=str(p)
    d=p[-1]
    d=int(d)
    if d in range(0,9,5):
       print(p,'divisible by 7 and is a multiple of 5')
    else:
        print(p,'divisible by 7 and is not a multiple of 5')
else:
    print(p,'is not divisible by 7')
# Out:
# enter a number 2107
# 2107 %7= 0
# 2107 divisible by 7 and is not a multiple of 5

# %% [markdown]
# # Q5

# %%
x=input('enter a number')
x=int(x)
i=1
for i in range(1,x,1):
    f=i+1
    i=int(i)
    f=f*i
print(f)
# Out:
# enter a number8
# 56

# %% [markdown]
# # Q6

# %%
s='hello team'
i=len(s)
i=int(i)
ch=s[0]
for p in range(2,i,2):
    ch=ch+s[p]
print(ch)
# Out:
# hlota

# %% [markdown]
# # Q7

# %%
p=input('enter the price')
p=int(p)
if p <= 200:
    d=p*10/100
elif p>=200 and p<500:
    d=p*30/100
else:
    d=p*50/100
print('the discount is ',d)
# Out:
# enter the price300
# the discount is  90.0

# %% [markdown]
# # Q 8

# %%
y=input('enter the year')
ii=y[2:-1]
ii=int(ii)
if ii!='00':
    y=int(y)
    a=y%4
    if a==0:
        print(y,'is a leap year')
    else:
        print(y,'is not a leap year')
# Out:
# enter the year2010
# 2010 is not a leap year
